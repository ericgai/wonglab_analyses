# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from utils import read_stats, assign_channels, plot_kde
import scipy
from itertools import combinations, product
from tqdm import tqdm
plt.rcParams['figure.figsize'] = [10,10]

# %%
channels={1:'CD11c',2:'Foxp3',3:'OVA',4:'CD3',5:'CD8a',6:'CellTracker Deep Red',7:'PD1',8:'MHCII',9:'CD4',10:'TCF1'}
DC_1L2_df=assign_channels(read_stats(r'..\240226_alum_flt3_control\1L2_Statistics'),channels)
DC_1L2_df['image']='1L2'
DC_1L3_df=assign_channels(read_stats(r'..\240226_alum_flt3_control\1L3_Statistics'),channels)
DC_1L3_df['image']='1L3'
DC_2L2_df=assign_channels(read_stats(r'..\240226_alum_flt3_control\2L2_Statistics'),channels)
DC_2L2_df['image']='2L2'
DC_2R2_df=assign_channels(read_stats(r'..\240226_alum_flt3_control\2R2_Statistics'),channels)
DC_2R2_df['image']='2R2'
# Out:
# d:\WongLabUsers\Eric\analysis\utils.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[title]=pd.read_csv(dir+r"\\"+file,header=2).iloc[:,0]
# d:\WongLabUsers\Eric\analysis\utils.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[title]=pd.read_csv(dir+r"\\"+file,header=2).iloc[:,0]
# ...

# %%
DC_ova_df=pd.concat((DC_2L2_df,DC_1L2_df,DC_1L3_df))
DC_crtl_df=pd.concat((DC_2R2_df,DC_2R1_df,DC_3R1_df))

# %%
# plt.hist(np.log10(DC['Intensity_Sum_OVA']+5e-1),label='OVA-AF555 injected',density=True)
# plt.hist(np.log10(DC_crtl_df['Intensity_Sum_OVA']+5e-1),label='control',density=True)
plt.hist(np.log10(DC_1L2_df['Intensity_Sum_OVA']+5e-1),label='1L2',density=True,alpha=0.5)
plt.hist(np.log10(DC_1L3_df['Intensity_Sum_OVA']+5e-1),label='1L3',density=True,alpha=0.5)
plt.hist(np.log10(DC_2L2_df['Intensity_Sum_OVA']+5e-1),label='2L2',density=True,alpha=0.5)
plt.hist(np.log10(DC_2R2_df['Intensity_Sum_OVA']+5e-1),label='2R2',density=True,alpha=0.5)

plt.legend()
plt.ylabel('Frequency')
plt.xlabel('log AF555 signal sum in cell')
# Out:
# Text(0.5, 0, 'log AF555 signal sum in cell')
